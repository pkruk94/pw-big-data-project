# %%
pip install nltk scipy scikit-learn pandas matplotlib gensim pyspark

# %%
import matplotlib.pyplot as plt
import pandas as pd
import nltk
import gensim

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql import functions as f
from pyspark.sql import Window
from pyspark.sql.types import StringType, DoubleType, IntegerType

spark = SparkSession.builder \
                    .appName('PK_BigData_Project') \
                    .config('spark.jars.packages', 'com.amazonaws:aws-java-sdk-bundle:1.12.170') \
                    .config('spark.jars.packages', 'org.apache.hadoop:hadoop-aws:3.3.3') \
                    .config("spark.driver.memory", "12g") \
                    .config("spark.executor.memory", "12g") \
                    .master('local[3]') \
                    .getOrCreate()

# %%
filePath = "s3a://pkruk-big-data/processed/"
tags_df = spark.read.parquet(filePath + 'Tags.parquet')
tags_15 = tags_df.select('tag_name').distinct()
tags_unique = list(map(lambda word: word.replace('-', '_'), [data[0] for data in tags_15.select('tag_name').collect()]))

# %%
import boto3

s3 = boto3.client('s3')

def read_from_s3():
    s3.download_file("pkruk-big-data", "articles/articles.txt", "articles.txt")

    with open("articles.txt") as f:
        articles = f.read().splitlines()

    return articles

# %% [markdown]
# ## 15. Badanie podobieństw między tagami

# %% [markdown]
# ### Klasteryzacja słów za pomocą k-means

# %%
def group_by_second(lst):
    return {k: [x for x, y in lst if y == k] for k in {y for x, y in lst}}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(tags_unique)

kmeans = KMeans(n_clusters=10)
kmeans.fit(X)

labels = kmeans.labels_

word_and_group = list(zip(tags_unique, labels))

# %%
result = group_by_second(word_and_group)

# %%
for key in result.keys():
    print(result[key])
    print()
# Out:
# ['star formation', 'neutron star', 'carbon star', 'eclipsing star systems', 'star evolution', 'star catalogues', 'star systems', 'star cluster', 'binary star', 'star maps', 'variable star', 'star', 'multiple star systems', 'star gazing', 'runaway star']
#
# ['horizon', 'event horizon', 'event horizon telescope', 'cosmological horizon', 'very high energetic event']
#
# ['rogue planet', 'standards', 'active galaxy', 'drizzle', 'm31', 'map', 'transits other than sun', 'brightness', 'big rip', 'planetary science', 'nova', 'image processing', 'orbital resonance', 'frame of reference', 'infrared', 'lunar eclipse', 'great red spot', 'spectral type', 'luminosity', 'light curve', 'detectors', 'iau', 'muon', 'magellanic cloud', 'standard candle', 'vera c rubin observatory', 'asteroid belt', 'orbit', 'serendipity', 'spectral', 'callisto', 'albedo', 'kuiper belt', 'neptune', 'differentiation', 'infinite', 'escape velocity', 'notation', 'gamma ray bursts', 'doppler effect', 'element', 'sun rays', 'eddington luminosity', 'orbital elements', 'algorithm', 'gravitational force', 'units', 'hypergiants', 'holographic principle', 'tracker', 'temperature', 'light pollution', 'magnitude', 'ascension', 'quantum mechanics', 'chthonian', 'ecliptic', 'mass', 'parallax', 'microlensing', 'nemesis', 'distances', 'ligo', 'archaeoastronomy', 'accretion discs', 'cyclones', 'meteoroid', 'mass gap', 'heat', 'special relativity', 'core', 'carbon cycle', 'vacuum', 'astropy', 'neutrinos', 'gamma rays', 'collision', 'projection', 'color index', 'soho', 'v838 monocerotis', 'retrograde orbit', 'visualization', 'lhb', 'near earth object', 'education', 'stellar population', 'correction', 'absolute magnitude', 'gas', 'trans neptunian object', 'nomenclature', 'mond', 'thermodynamics', 'wolf rayet', 'sloan dss', 'charge coupled devices', 'io', 'blazars', 'visible light', 'messier catalog', 'high energy astrophysics', 'globular clusters', 'protostar', 'milky way', 'sunyaev zeldovich effect', 'observation campaign', 'fusion', 'terminology', 'mirror', 'crater', 'wavelength', 'planetary atmosphere', 'gravitational lensing', 'potential energy', 'stellarium', 'astronomical unit', 'cartography', 'parsec', 'surface', 'zodiacal light', '99942 apophis', 'navigation', 'impact', 'meteorite', 'origin of life', 'keplers laws', 'collimation', 'extinction', 'multiverse', 'no hair conjecture', 'conjunction', 'adaptive optics', 'oumuamua', 'planetary transits', 'instruments', 'astrophysics', 'analemma', 'turbulence', 'future', 'cosmic microwave background', 'radio', 'betelgeuse', 'spectroscopy', 'flare', 'angular resolution', 'asteroids', 'csst', 'eyepiece', 'k2', 'dark matter', 'comets', 'hypothetical', 'm87', 'proto planetary disk', 'magnetic field', 'light', 'stellar classification', 'pressure', 'e elt', 'drake equation', 'tidal forces', 'estimate', 'solar system', 't tauri stars', 'resource request', 'formation', 'stellar remnants', 'particles', 'earth', 'neural networks', 'software', 'dark energy', 'nebulae', 'kilonova', 'hipparcos', 'nicer', 'contact binaries', 'n body simulations', 'ice', 'tweakreg', 'density', 'clock', 'solar wind', 'water', 'radial velocity', 'lofar', 'photography', 'hot jupiter', 'seyfert galaxy', 'observatory', 'orbital migration', 'nebula', 'dust', 'cosmological inflation', 'parker solar probe', 'moonlet', 'alma', 'iss', 'initial mass function', 'opacity', 'mass loss', 'oort cloud', 'radius', 'big bang theory', 'umbra', 'red supergiant', 'life', 'elliptic', 'trojan asteroids', 'prediction', 'declination', 'javascript', 'earth like planet', 'mars', 'axion', 'inclination', 'triton', 'nucleosynthesis', 'seti', 'tess', 'trappist 1', 'stellar structure', 'barlow', 'accretion', 'proton', 'plasma physics', 'sunset', 'ions', 'azimuth', 'solar storm', 'photometry', 'alignment', 'velocity', 'pulsar', 'climate', 'eccentric orbit', 'post processing', 'abiogenesis', 'kbo', 'nasa', 'corona', 'history', 'movement', 'app', 'friedmann equations', 'right ascension', 'artificial satellite', 'data analysis', 'main sequence', 'magnetar', 'angular diameter', 'solar eclipse', 'the moon', 'centaur', 'polaris', 'fits header', 'skyfield', 'mathematics', 'sunrise', 'bow shock', 'liquid', 'jupiter', 'chandra', 'cosmic ray', 'alerts', 'c2014 un271 bernardinelli bernstein', 'ceres', '67p', 'diy', 'dispersion', 'asteroseismology', 'gravitation', 'photons ...
#
# ['fate of universe', 'universe', 'early universe', 'observable universe', 'universe sandbox']
#
# ['interstellar', 'interstellar travel', 'circumgalactic medium', 'interplanetary medium', 'interstellar medium']
#
# ['space', 'very large telescope', 'cassegrain telescope', 'telescope lens', 'space geometry', 'telescope care', 'giant magellan telescope', 'refractor telescope', 'space time', 'rc telescope', 'james webb space telescope', 'hubble telescope', 'telescope', 'large binocular telescope', 'dobsonian telescope', 'space debris', 'newtonian telescope', 'space probe', 'nancy grace roman telescope', 'space travel', 'telescope making', 'intergalactic space', 'radio telescope', 'space telescope']
#
# ['stellar dynamics', 'galactic evolution', 'galactic center', 'galactic halo', 'galactic dynamics']
#
# ['dwarf planets', 'dwarf galaxy', 'brown dwarf', 'white dwarf', 'dwarf star', 'red dwarf']
#
# ['sidereal period', 'synodic period', 'period']
#
# ['observational astronomy', 'gravitational wave astronomy', 'positional astronomy', 'time domain astronomy', 'time dilation', 'radio astronomy', 'time', 'fundamental astronomy', 'astronomy site']

# %% [markdown]
# ### Model semantyczny: Można użyć modelu semantycznego, takiego jak word2vec lub GloVe, aby porównać semantyczne relacje między słowami i zobaczyć, czy są blisko siebie.

# %%
def get_similar_words(word):
    similar_words = model.wv.most_similar(positive=[word])
    filtered_words = [word[0] for word in similar_words if word[1] > 0.6]
    return filtered_words

# %%
import gensim
from gensim.models import Word2Vec

astronomy_articles = [text]

model = Word2Vec(word_list, vector_size=100, window=5, min_count=1, workers=4)

# %%
for word in tags_unique:
    similar_words = get_similar_words(word)
    print("Słowo:", word)
    print("Podobne słowa:", similar_words)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-57c1d9c272c2> in <module>
#       1 for word in tags_unique:
# ----> 2     similar_words = get_similar_words(word)
#       3     print("Słowo:", word)
#       4     print("Podobne słowa:", similar_words)
#
# <ipython-input-30-35b10ceb1231> in get_similar_words(word)
#       1 def get_similar_words(word):
# ----> 2     similar_words = model.wv.most_similar(positive=[word])
#       3     filtered_words = [word[0] for word in similar_words if word[1] > 0.6]
#       4     return filtered_words
#
# ~/.local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     840
#     841         # compute the weighted average of all keys
# --> 842         mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     843         all_keys = [
#     844             self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#
# ~/.local/lib/python3.7/site-packages/gensim/models/keyedvectors.py in get_mean_vector(self, keys, weights, pre_normalize, post_normalize, ignore_missing)
#     517                 total_weight += abs(weights[idx])
#     518             elif not ignore_missing:
# --> 519                 raise KeyError(f"Key '{key}' not present in vocabulary")
#     520
#     521         if(total_weight > 0):
#
# KeyError: "Key 'rogue planet' not present in vocabulary"

# %% [markdown]
# ### Słownik synonimów: Można użyć gotowego słownika synonimów, aby zobaczyć, czy dane słowa są zdefiniowane jako synonimy. Po prostu sprawdzam synonimy dla tego słowa, niekoniecznie podobieńśtwa z lista tagów

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet

# %%
def get_synonyms(word):
    synonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    return set(synonyms)

# %%
for word in tags_unique:
    synonyms = get_synonyms(word)
    if len(synonyms) != 0:
        print("Słowo:", word)
        print("Synonimy:", synonyms)
        print()
# Out:
# Słowo: standards
# Synonimy: {'monetary_standard', 'measure', 'touchstone', 'criterion', 'banner', 'standard'}
#
# Słowo: drizzle
# Synonimy: {'drizzle', 'mizzle', 'moisten'}
#
# Słowo: map
# Synonimy: {'map', 'function', 'single-valued_function', 'mapping', 'map_out', 'mathematical_function', 'represent'}
#
# Słowo: interstellar
# Synonimy: {'interstellar'}
#
# Słowo: brightness
# Synonimy: {'light', 'luminance', 'brightness', 'smartness', 'brightness_level', 'luminosity', 'luminousness', 'cleverness'}
#
# Słowo: nova
# Synonimy: {'nova'}
#
# Słowo: infrared
# Synonimy: {'infrared_emission', 'infrared_frequency', 'infrared_radiation', 'infrared', 'infrared_light'}
#
# Słowo: space
# Synonimy: {'distance', 'blank', 'quad', 'space', 'blank_space', 'place', 'outer_space', 'infinite'}
#
# Słowo: luminosity
# Synonimy: {'light', 'luminance', 'brightness', 'brightness_level', 'luminosity', 'luminousness'}
#
# Słowo: detectors
# Synonimy: {'sensing_element', 'demodulator', 'detector', 'sensor'}
#
# Słowo: muon
# Synonimy: {'mu-meson', 'muon', 'negative_muon'}
#
# Słowo: orbit
# Synonimy: {'ambit', 'reach', 'range', 'revolve', 'compass', 'orbital_cavity', 'area', 'orbit', 'celestial_orbit', 'field', 'eye_socket', 'cranial_orbit', 'scope', 'orb', 'electron_orbit', 'domain', 'arena', 'sphere'}
#
# Słowo: serendipity
# Synonimy: {'serendipity'}
#
# Słowo: spectral
# Synonimy: {'phantasmal', 'ghostlike', 'apparitional', 'ghostly', 'spectral', 'spiritual'}
#
# Słowo: callisto
# Synonimy: {'Callisto'}
#
# Słowo: albedo
# Synonimy: {'reflective_power', 'albedo'}
#
# Słowo: neptune
# Synonimy: {'Neptune'}
#
# Słowo: differentiation
# Synonimy: {'differentiation', 'distinction', 'specialization', 'specialisation'}
#
# Słowo: infinite
# Synonimy: {'multitudinous', 'myriad', 'numberless', 'uncounted', 'space', 'unnumerable', 'non-finite', 'countless', 'innumerous', 'innumerable', 'infinite', 'unnumberable', 'unnumbered'}
#
# Słowo: notation
# Synonimy: {'annotation', 'notational_system', 'note', 'notation'}
#
# Słowo: element
# Synonimy: {'element', 'factor', 'component', 'constituent', 'chemical_element', 'ingredient'}
#
# Słowo: algorithm
# Synonimy: {'algorithmic_rule', 'algorithm', 'algorithmic_program'}
#
# Słowo: units
# Synonimy: {'unit', 'building_block', 'whole', 'social_unit', 'unit_of_measurement'}
#
# Słowo: tracker
# Synonimy: {'tracker'}
#
# Słowo: temperature
# Synonimy: {'temperature'}
#
# Słowo: magnitude
# Synonimy: {'order_of_magnitude', 'magnitude'}
#
# Słowo: ascension
# Synonimy: {'Ascension_of_Christ', 'rising', 'rise', 'ascension', 'Ascension_of_the_Lord', 'Ascension_Day', 'ascending', 'ascent', 'Ascension'}
#
# Słowo: chthonian
# Synonimy: {'nether', 'chthonic', 'chthonian'}
#
# Słowo: ecliptic
# Synonimy: {'ecliptic'}
#
# Słowo: mass
# Synonimy: {'quite_a_little', 'raft', 'tidy_sum', 'deal', 'mass', 'Mass', 'multitude', 'plenty', 'muckle', 'people', 'mountain', 'mess', 'passel', 'spate', 'the_great_unwashed', 'sight', 'volume', 'aggregated', 'lot', 'aggregative', 'great_deal', 'masses', 'mickle', 'peck', 'stack', 'wad', 'hoi_polloi', 'pile', 'mint', 'good_deal', 'batch', 'bulk', 'pot', 'hatful', 'aggregate', 'heap', 'slew', 'flock'}
#
# Słowo: parallax
# Synonimy: {'parallax'}
#
# Słowo: nemesis
# Synonimy: {'curse', 'bane', 'Nemesis', 'scourge', 'nemesis'}
#
# Słowo: distances
# Synonimy: {'distance', 'length', 'aloofness', 'space', 'outstrip', 'outdistance'}
#
# Słowo: cyclones
# Synonimy: {'cyclone'}
#
# Słowo: meteoroid
# Synonimy: {'meteor', 'meteoroid'}
#
# Słowo: heat
# Synonimy: {'passion', 'heat_energy', 'heating', 'heat_up', 'rut', 'ignite', 'wake', 'oestrus', 'heating_plant', 'heating_system', 'heat', 'hotness', 'inflame', 'warmth', 'stir_up', 'high_temperature', 'estrus', 'hot_up', 'fire_up'}
#
# Słowo: universe
# Synonimy: {'creation', 'world', 'population', 'macrocosm', 'cosmos', 'universe_of_discourse', 'existence', 'universe'}
#
# Słowo: core
# Synonimy: {'heart', 'centre', 'essence', 'nitty-gritty', 'CORE', 'nub', 'pith', 'heart_and_soul', 'sum', 'meat', 'kernel', 'inwardness', 'center', 'effect', 'nucleus', 'gist', 'magnetic_core', 'substance', 'core_group', 'burden', 'marrow', 'Congress_of_Racial_Equality', 'core'}
#
# Słowo: vacuum
# Synonimy: {'emptiness', 'vacuity', 'vacuum', 'vacuum_cleaner', 'void', 'vacancy', 'vacuum-clean', 'hoover'}
#
# Słowo: neutrinos
# Synonimy: {'neutrino'}
#
# Słowo: collision
# Synonimy: {'collision', 'hit'}
#
# Słowo: projection
# Synonimy: {'protrusion', 'expulsion', 'jut', 'jutting', 'projection', 'sound_projection', 'project', 'forcing_out', 'acoustic_projection', 'ejection'}
#
# Słowo: soho
# Synonimy: {'Soho', 'SoHo', 'South_of_Houston'}
#
# Słowo: visualization
# Synonimy: {'visual_image', 'visualisation', 'visualization'}
#
# Słowo: education
# Synonimy: {'Education', 'pedagogy', 'Education_Department', 'Department_of_Education', 'training', 'instruction', 'education', 'educational_activity', 'teaching', 'breeding', 'didactics'}
#
# Słowo: correction
# Synonimy: {'correction', 'chastening', 'discipline', 'rectification', 'chastisement', 'fudge_factor'}
#
# Słowo: gas
# Synonimy: {'boast', 'swash', 'petrol', 'accelerator_pedal', 'flatulence', 'gas_pedal', 'accelerator', 'gaseous_state', 'brag', 'bluster', 'vaunt', 'gasolene', 'gun', 'natural_gas', 'flatulency', 'gas', 'throttle', 'gasconade', 'blow', 'gasoline', 'shoot_a_line', 'tout'}
#
# Słowo: horizon
# Synonimy: {'celestial_horizon', 'apparent_horizon', 'view', 'purview', 'sensible_horizon', 'visible_horizon', 'horizon', 'skyline'}
#
# Słowo: nomenclature
# Synonimy: {'nomenclature', 'terminology', 'language'}
#
# Słowo: thermodynamics
# Synonimy: {'thermodynamics'}
#
# Słowo: io
# Synonimy: {'Io'}
#
# Słowo: fusion
# Synonimy: {'nuclear_fusion', 'nuclear_fusion_reaction', 'coalition', 'spinal_fusion', 'fusion', 'optical_fusion', 'merger', 'unification'}
#
# Słowo: terminology
# Synonimy: {'nomenclature', 'terminology', 'language'}
#
# Słowo: mirror
# Synonimy: {'mirror'}
#
# Słowo: crater
# Synonimy: {'volcanic_crater', 'crater', 'Crater'}
#
# Słowo: wavelength
# Synonimy: {'wavelength'}
#
# Słowo: cartography
# Synonimy: {'cartography', 'mapmaking'}
#
# Słowo: parsec
# Synonimy: {'secpar', 'parsec'}
#
# Słowo: surface
# Synonimy: {'airfoil', 'aerofoil', 'rise', 'coat', 'turn_up', 'rise_up', 'show_up', 'come_out', 'come_up', "Earth's_surface", 'control_surface', 'open', 'come_on', 'surface'}
#
# Słowo: navigation
# Synonimy: {'seafaring', 'navigation', 'pilotage', 'sailing', 'piloting'}
#
# Słowo: impact
# Synonimy: {'impact', 'wallop', 'touch', 'shock', 'affect', 'bear_on', 'bear_upon', 'impingement', 'encroachment', 'touch_on'}
#
# Słowo: meteorite
# Synonimy: {'meteorite'}
#
# Słowo: collimation
# Synonimy: {'collimation'}
#
# Słowo: extinction
# Synonimy: {'extermination', 'extinction', 'experimental_extinction', 'extinguishing', 'quenching', 'defunctness'}
#
# Słowo: conjunction
# Synonimy: {'colligation', 'junction', 'conjugation', 'connective', 'co-occurrence', 'alignment', 'conjunctive', 'conjunction', 'coincidence', 'concurrence', 'continuative'}
#
# Słowo: instruments
# Synonimy: {"cat's-paw", 'pawn', 'legal_document', 'instrumentate', 'official_document', 'musical_instrument', 'instrumental_role', 'legal_instrument', 'instrument', 'tool'}
#
# Słowo: astrophysics
# Synonimy: {'astrophysics'}
#
# Słowo: turbulence
# Synonimy: {'upheaval', 'turbulency', 'Sturm_und_Drang', 'turbulence'}
#
# Słowo: future
# Synonimy: {'future', 'next', 'succeeding', 'time_to_come', 'hereafter', 'future_tense', 'futurity'}
#
# Słowo: radio
# Synonimy: {'tuner', 'radio', 'receiving_set', 'radio_receiver', 'radio_set', 'wireless', 'radiocommunication'}
#
# Słowo: betelgeuse
# Synonimy: {'Alpha_Orionis', 'Betelgeuse'}
#
# Słowo: spectroscopy
# Synonimy: {'spectrometry', 'spectroscopy', 'spectroscopic_analysis', 'spectrum_analysis', 'spectrographic_analysis'}
#
# Słowo: flare
# Synonimy: {'burn_up', 'solar_flare', 'flare_out', 'flash', 'flare', 'break_open', 'flare_up', 'blaze_up', 'flame_up', 'erupt', 'flame', 'flair', 'burst_out', 'irrupt', 'flare_pass'}
#
# Słowo: asteroids
# Synonimy: {'asteroid'}
#
# Słowo: eyepiece
# Synonimy: {'ocular', 'eyepiece'}
#
# Słowo: k2
# Synonimy: {'K2', 'Godwin_Austen', 'Mount_Godwin_Austen', 'Dapsang'}
#
# Słowo: comets
# Synonimy: {'comet'}
#
# Słowo: hypothetical
# Synonimy: {'suppositional', 'suppositious', 'hypothetic', 'conjectural', 'hypothetical', 'supposed', 'supposititious', 'divinatory'}
#
# Słowo: light
# Synonimy: {'unaccented', 'illuminate', 'illumination', 'luminance', 'get_off', 'lightly', 'sparkle', 'swooning', 'scant', 'light-headed', 'Light', 'low-cal', 'wanton', 'light-colored', 'easy', 'light_source', 'Christ_Within', 'ignite', 'luminousness', 'Inner_Light', 'lightsome', 'lightheaded', 'brightness', 'dismount', 'light_up', 'sluttish', 'unhorse', 'brightness_level', 'lighter', 'short', 'fall', 'unclouded', 'tripping', 'light', 'calorie-free', 'get_down', 'alight', 'ignitor', 'clear', 'idle', 'clean', 'faint', 'lighting', 'weak', 'igniter', 'illume', 'loose', 'perch', 'spark', 'visible_radiation', 'lightness', 'illumine', 'promiscuous', 'fire_up', 'luminosity', 'wakeful', 'Light_Within', 'lite', 'abstemious', 'twinkle', 'visible_light'}
#
# Słowo: pressure
# Synonimy: {'insistency', 'squeeze', 'insistence', 'press', 'blackjack', 'coerce', 'force', 'atmospheric_pressure', 'pressure', 'pressure_sensation', 'pressure_level', 'hale', 'imperativeness', 'pressing', 'air_pressure', 'blackmail', 'force_per_unit_area'}
#
# Słowo: estimate
# Synonimy: {'judge', 'approximation', 'estimate', 'reckon', 'guess', 'calculate', 'count_on', 'figure', 'gauge', 'forecast', 'approximate', 'estimation', 'appraisal', 'idea'}
#
# Słowo: formation
# Synonimy: {'organisation', 'constitution', 'establishment', 'shaping', 'organization', 'formation', 'geological_formation'}
#
# Słowo: particles
# Synonimy: {'particle', 'speck', 'mote', 'atom', 'molecule', 'corpuscle', 'subatomic_particle'}
#
# Słowo: earth
# Synonimy: {'globe', 'world', 'terra_firma', 'dry_land', 'land', 'worldly_concern', 'Earth', 'earth', 'earthly_concern', 'ground', 'solid_ground'}
#
# Słowo: software
# Synonimy: {'software_system', 'software', 'software_package', 'computer_software', 'software_program', 'package'}
#
# Słowo: nebulae
# Synonimy: {'nebula'}
#
# Słowo: nicer
# Synonimy: {'gracious', 'courteous', 'squeamish', 'overnice', 'decent', 'dainty', 'nice', 'prissy', 'skillful'}
#
# Słowo: ice
# Synonimy: {'ice-skating_rink', 'glass', 'frosting', 'ice', 'meth', 'chalk', 'ICE', 'crank', 'internal-combustion_engine', 'frappe', 'deoxyephedrine', 'ice_rink', 'frost', 'chicken_feed', 'sparkler', 'icing', 'methamphetamine', 'shabu', 'Methedrine', 'trash', 'methamphetamine_hydrochloride', 'water_ice'}
#
# Słowo: density
# Synonimy: {'denseness', 'concentration', 'tightness', 'density', 'compactness'}
#
# Słowo: clock
# Synonimy: {'clock', 'time'}
#
# Słowo: water
# Synonimy: {'body_of_water', 'piddle', 'water_system', 'urine', 'piss', 'water_supply', 'irrigate', 'pee', 'weewee', 'water', 'H2O'}
#
# Słowo: photography
# Synonimy: {'picture_taking', 'photography'}
#
# Słowo: observatory
# Synonimy: {'observatory', 'observation_tower', 'lookout_station', 'lookout'}
#
# Słowo: nebula
# Synonimy: {'nebula'}
#
# Słowo: dust
# Synonimy: {'junk', 'debris', 'scatter', 'dot', 'disperse', 'rubble', 'sprinkle', 'dust', 'detritus'}
#
# Słowo: iss
# Synonimy: {'ace', 'single', 'unity', 'iodine', 'atomic_number_53', '1', 'I', 'one', 'i', 'iodin'}
#
# Słowo: opacity
# Synonimy: {'opaqueness', 'opacity'}
#
# Słowo: radius
# Synonimy: {'radius', 'wheel_spoke', 'spoke', 'r'}
#
# Słowo: umbra
# Synonimy: {'umbra'}
#
# Słowo: life
# Synonimy: {'liveliness', 'life', 'sprightliness', 'lifetime', 'biography', 'life_story', 'life_sentence', 'aliveness', 'life-time', 'spirit', 'lifespan', 'life_history', 'animation', 'living'}
#
# Słowo: elliptic
# Synonimy: {'elliptical', 'ovoid', 'egg-shaped', 'oval', 'oval-shaped', 'prolate', 'oviform', 'elliptic', 'ovate'}
#
# Słowo: prediction
# Synonimy: {'prediction', 'prognostication', 'anticipation', 'forecasting', 'prevision', 'foretelling'}
#
# Słowo: declination
# Synonimy: {'decline', 'declivity', 'declination', 'regrets', 'downslope', 'declension', 'fall', 'celestial_latitude', 'descent', 'dec'}
#
# Słowo: mars
# Synonimy: {'Red_Planet', 'mutilate', 'Mar', 'vitiate', 'spoil', 'deflower', 'blemish', 'March', 'defect', 'impair', 'Mars', 'mar'}
#
# Słowo: inclination
# Synonimy: {'disposition', 'inclining', 'tilt', 'dip', 'lean', 'inclination', 'angle_of_inclination', 'leaning', 'magnetic_inclination', 'magnetic_dip', 'angle_of_dip', 'tendency', 'inclination_of_an_orbit', 'list'}
#
# Słowo: triton
# Synonimy: {'newt', 'Triton', 'triton'}
#
# Słowo: nucleosynthesis
# Synonimy: {'nucleosynthesis'}
#
# Słowo: telescope
# Synonimy: {'telescope', 'scope'}
#
# Słowo: tess
# Synonimy: {'ti', 'atomic_number_52', 'Te', 'te', 'tellurium', 'si'}
#
# Słowo: accretion
# Synonimy: {'accretion', 'accumulation'}
#
# Słowo: proton
# Synonimy: {'proton'}
#
# Słowo: sunset
# Synonimy: {'sunset', 'sundown'}
#
# Słowo: ions
# Synonimy: {'ion'}
#
# Słowo: azimuth
# Synonimy: {'azimuth', 'AZ'}
#
# Słowo: photometry
# Synonimy: {'photometry'}
#
# Słowo: alignment
# Synonimy: {'alinement', 'alignment', 'coalition', 'alliance', 'conjunction'}
#
# Słowo: velocity
# Synonimy: {'velocity', 'speed'}
#
# Słowo: pulsar
# Synonimy: {'pulsar'}
#
# Słowo: climate
# Synonimy: {'climate', 'clime', 'mood'}
#
# Słowo: abiogenesis
# Synonimy: {'abiogenesis', 'autogenesis', 'autogeny', 'spontaneous_generation'}
#
# Słowo: kbo
# Synonimy: {'KBO', 'Kuiper_belt_object'}
#
# Słowo: nasa
# Synonimy: {'NASA', 'National_Aeronautics_and_Space_Administration'}
#
# Słowo: corona
# Synonimy: {"Saint_Elmo's_light", 'corposant', "Saint_Ulmo's_fire", "St._Elmo's_fire", 'corona_discharge', "Saint_Elmo's_fire", 'electric_glow', 'aureole', 'corona', "Saint_Ulmo's_light"}
#
# Słowo: history
# Synonimy: {'chronicle', 'history', 'story', 'account'}
#
# Słowo: movement
# Synonimy: {'drift', 'drive', 'bowel_movement', 'campaign', 'cause', 'move', 'apparent_movement', 'bm', 'motion', 'motility', 'crusade', 'apparent_motion', 'movement', 'front', 'effort', 'trend', 'social_movement'}
#
# Słowo: centaur
# Synonimy: {'Centaurus', 'centaur', 'Centaur'}
#
# Słowo: polaris
# Synonimy: {'polestar', 'North_Star', 'polar_star', 'Polaris', 'pole_star'}
#
# Słowo: mathematics
# Synonimy: {'maths', 'mathematics', 'math'}
#
# Słowo: sunrise
# Synonimy: {'dawning', 'dayspring', 'sunup', 'cockcrow', 'dawn', 'aurora', 'morning', 'first_light', 'break_of_the_day', 'sunrise', 'daybreak', 'break_of_day'}
#
# Słowo: liquid
# Synonimy: {'limpid', 'swimming', 'liquidity', 'melted', 'fluid', 'smooth', 'liquid', 'liquidness', 'fluent', 'liquified', 'liquid_state'}
#
# Słowo: jupiter
# Synonimy: {'Jove', 'Jupiter'}
#
# Słowo: alerts
# Synonimy: {'alarum', 'alarm', 'warning_signal', 'qui_vive', 'alerting', 'alert'}
#
# Słowo: ceres
# Synonimy: {'cere', 'Ceres'}
#
# Słowo: dispersion
# Synonimy: {'dispersion', 'dispersal', 'distribution', 'diffusion', 'scattering', 'dissemination'}
#
# Słowo: gravitation
# Synonimy: {'gravity', 'gravitational_force', 'gravitational_attraction', 'gravitation'}
#
# Słowo: photons
# Synonimy: {'photon'}
#
# Słowo: pole
# Synonimy: {'celestial_pole', 'perch', 'punt', 'terminal', 'magnetic_pole', 'pole', 'rod', 'Pole'}
#
# Słowo: planet
# Synonimy: {'major_planet', 'planet', 'satellite'}
#
# Słowo: galaxy
# Synonimy: {'galax', 'coltsfoot', 'Galax_urceolata', 'wandflower', 'extragalactic_nebula', 'beetleweed', 'galaxy'}
#
# Słowo: sunspots
# Synonimy: {'macula', 'sunspot'}
#
# Słowo: modeling
# Synonimy: {'posture', 'molding', 'pattern', 'model', 'clay_sculpture', 'mould', 'modelling', 'mock_up', 'modeling', 'simulate', 'mold', 'pose', 'sit', 'moulding'}
#
# Słowo: redshift
# Synonimy: {'redshift', 'red_shift'}
#
# Słowo: geysers
# Synonimy: {'geyser'}
#
# Słowo: age
# Synonimy: {'mature', 'eld', 'historic_period', 'old_age', 'get_on', 'years', 'geezerhood', 'maturate', 'age', 'senesce', 'long_time'}
#
# Słowo: astrometry
# Synonimy: {'astrometry'}
#
# Słowo: quasars
# Synonimy: {'quasi-stellar_radio_source', 'quasar'}
#
# Słowo: gravity
# Synonimy: {'sobriety', 'solemnity', 'sombreness', 'gravitation', 'gravity', 'gravitational_force', 'somberness', 'graveness', 'soberness', 'gravitational_attraction'}
#
# Słowo: color
# Synonimy: {'discolor', 'distort', 'colorize', 'color_in', 'colour_in', 'semblance', 'colorise', 'colouring_material', 'emblazon', 'people_of_color', 'coloring', 'people_of_colour', 'tinge', 'gloss', 'colourise', 'colour', 'vividness', 'discolour', 'coloring_material', 'colourize', 'color', 'coloration', 'colouring', 'colouration'}
#
# Słowo: optics
# Synonimy: {'optics', 'optic', 'eye', 'oculus'}
#
# Słowo: binoculars
# Synonimy: {'opera_glasses', 'binoculars', 'field_glasses'}
#
# Słowo: rotation
# Synonimy: {'rotary_motion', 'rotation', 'revolution', 'gyration'}
#
# Słowo: theory
# Synonimy: {'theory', 'hypothesis', 'possibility'}
#
# Słowo: spectrometry
# Synonimy: {'spectrometry', 'spectroscopy', 'spectroscopic_analysis', 'spectrum_analysis', 'spectrographic_analysis'}
#
# Słowo: sofia
# Synonimy: {'Serdica', 'Bulgarian_capital', 'Sofia'}
#
# Słowo: neutrons
# Synonimy: {'neutron'}
#
# Słowo: photosphere
# Synonimy: {'photosphere'}
#
# Słowo: period
# Synonimy: {'menstruation', 'point', 'time_period', 'menses', 'flow', 'full_stop', 'stop', 'period', 'full_point', 'geological_period', 'menstruum', 'catamenia', 'period_of_time'}
#
# Słowo: metal
# Synonimy: {'metal', 'metallic_element', 'alloy', 'metallic'}
#
# Słowo: astrobiology
# Synonimy: {'exobiology', 'astrobiology', 'space_biology'}
#
# Słowo: gaia
# Synonimy: {'Ge', 'Gaea', 'Gaia'}
#
# Słowo: supernova
# Synonimy: {'supernova'}
#
# Słowo: wormhole
# Synonimy: {'wormhole'}
#
# Słowo: theories
# Synonimy: {'theory', 'hypothesis', 'possibility'}
#
# Słowo: sound
# Synonimy: {'speech_sound', 'heavy', 'fathom', 'good', 'reasoned', 'profound', 'phone', 'vocalise', 'wakeless', 'audio', 'go', 'auditory_sensation', 'voice', 'levelheaded', 'healthy', 'effectual', 'level-headed', 'strait', 'legal', 'sound', 'well-grounded', 'intelligent', 'vocalize'}
#
# Słowo: methane
# Synonimy: {'methane'}
#
# Słowo: uranus
# Synonimy: {'Ouranos', 'Uranus'}
#
# Słowo: solstice
# Synonimy: {'solstice'}
#
# Słowo: saturn
# Synonimy: {'Saturn'}
#
# Słowo: geology
# Synonimy: {'geology'}
#
# Słowo: precession
# Synonimy: {'precedence', 'precedency', 'precession'}
#
# Słowo: pisces
# Synonimy: {'Pisces', 'Pisces_the_Fishes', 'Fish'}
#
# Słowo: phobos
# Synonimy: {'Phobos'}
#
# Słowo: theia
# Synonimy: {'Thea', 'Theia'}
#
# Słowo: exposure
# Synonimy: {'picture', 'exposure', 'photograph', 'pic', 'photo', 'vulnerability'}
#
# Słowo: kinematics
# Synonimy: {'kinematics'}
#
# Słowo: radiation
# Synonimy: {'radiation_syndrome', 'radiation_sickness', 'radiation', 'radiation_therapy', 'radiotherapy', 'irradiation', 'radioactivity', 'actinotherapy'}
#
# Słowo: graviton
# Synonimy: {'graviton'}
#
# Słowo: polarization
# Synonimy: {'polarization', 'polarisation'}
#
# Słowo: spectra
# Synonimy: {'spectrum'}
#
# Słowo: satellite
# Synonimy: {'artificial_satellite', 'planet', 'orbiter', 'satellite'}
#
# Słowo: singularity
# Synonimy: {'uniqueness', 'singularity'}
#
# Słowo: molecules
# Synonimy: {'particle', 'speck', 'mote', 'atom', 'molecule', 'corpuscle'}
#
# Słowo: classification
# Synonimy: {'categorization', 'assortment', 'compartmentalisation', 'compartmentalization', 'categorisation', 'sorting', 'classification'}
#
# Słowo: orion
# Synonimy: {'Hunter', 'Orion'}
#
# Słowo: helium
# Synonimy: {'atomic_number_2', 'helium', 'He'}
#
# Słowo: flux
# Synonimy: {'merge', 'magnetic_flux', 'blend', 'state_of_flux', 'fluxion', 'coalesce', 'liquefy', 'magnetic_field', 'flux_density', 'flux', 'conflate', 'flow', 'liquify', 'combine', 'commingle', 'fuse', 'mix', 'meld', 'immix'}
#
# Słowo: matter
# Synonimy: {'matter', 'subject', 'issue', 'count', 'weigh', 'thing', 'affair', 'topic'}
#
# Słowo: homogeneity
# Synonimy: {'homogeneousness', 'homogeneity'}
#
# Słowo: mercury
# Synonimy: {'hydrargyrum', 'atomic_number_80', 'Hg', 'mercury', 'quicksilver', 'Mercury'}
#
# Słowo: deimos
# Synonimy: {'Deimos'}
#
# Słowo: time
# Synonimy: {'clip', 'fourth_dimension', 'metre', 'sentence', 'meter', 'clock_time', 'clock', 'time', 'prison_term'}
#
# Słowo: orrery
# Synonimy: {'orrery'}
#
# Słowo: definition
# Synonimy: {'definition'}
#
# Słowo: hyperion
# Synonimy: {'Hyperion'}
#
# Słowo: naming
# Synonimy: {'nominate', 'naming', 'name', 'constitute', 'mention', 'assignment', 'identify', 'designation', 'advert', 'key_out', 'call', 'describe', 'diagnose', 'discover', 'cite', 'make', 'key', 'appellative', 'appoint', 'refer', 'bring_up', 'distinguish', 'appointment', 'list'}
#
# Słowo: communication
# Synonimy: {'communication', 'communicating'}
#
# Słowo: eccentricity
# Synonimy: {'eccentricity'}
#
# Słowo: untagged
# Synonimy: {'unlabelled', 'untagged', 'unlabeled'}
#
# Słowo: explosion
# Synonimy: {'plosion', 'blowup', 'burst', 'explosion', 'detonation'}
#
# Słowo: cosmology
# Synonimy: {'cosmogeny', 'cosmogony', 'cosmology'}
#
# Słowo: star
# Synonimy: {'maven', 'starring', 'sensation', 'wizard', 'virtuoso', 'superstar', 'wiz', 'mavin', 'prima', 'star', 'principal', 'stellar', 'ace', 'adept', 'lead', 'asterisk', 'hotshot', 'leading', 'whiz', 'champion', 'genius', 'whizz', 'headliner', 'star_topology'}
#
# Słowo: expansion
# Synonimy: {'expansion', 'elaboration', 'enlargement', 'expanding_upon'}
#
# Słowo: weather
# Synonimy: {'brave_out', 'upwind', 'atmospheric_condition', 'brave', 'weather', 'weather_condition', 'conditions', 'endure'}
#
# Słowo: volcanism
# Synonimy: {'volcanism'}
#
# Słowo: obliquity
# Synonimy: {'obliquity', 'deceptiveness', 'asynclitism'}
#
# Słowo: equinox
# Synonimy: {'equinoctial_point', 'equinox'}
#
# Słowo: zodiac
# Synonimy: {'zodiac'}
#
# Słowo: information
# Synonimy: {'selective_information', 'entropy', 'info', 'data', 'information'}
#
# Słowo: radar
# Synonimy: {'radiolocation', 'radar', 'radio_detection_and_ranging', 'microwave_radar'}
#
# Słowo: symbols
# Synonimy: {'symbolic_representation', 'symbol', 'symbolization', 'symbolisation'}
#
# Słowo: meteor
# Synonimy: {'shooting_star', 'meteor', 'meteoroid'}
#
# Słowo: pluto
# Synonimy: {'Hades', 'Pluto', 'Aidoneus', 'Aides'}
#
# Słowo: venus
# Synonimy: {'Venus', 'Urania', 'genus_Venus'}
#
# Słowo: fits
# Synonimy: {'scene', 'suit', 'burst', 'jibe', 'tally', 'tantrum', 'conform_to', 'check', 'equip', 'agree', 'match', 'go', 'outfit', 'conniption', 'accommodate', 'gibe', 'correspond', 'fit_out', 'convulsion', 'fit', 'paroxysm', 'meet'}
#
# Słowo: europa
# Synonimy: {'Europa'}
#
# Słowo: aurora
# Synonimy: {'dawning', 'dayspring', 'sunup', 'Aurora', 'cockcrow', 'dawn', 'aurora', 'morning', 'first_light', 'break_of_the_day', 'sunrise', 'daybreak', 'break_of_day'}
#
# Słowo: antimatter
# Synonimy: {'antimatter'}
#
# Słowo: python
# Synonimy: {'Python', 'python'}
#
# Słowo: twilight
# Synonimy: {'twilit', 'dusky', 'evenfall', 'twilight', 'nightfall', 'crepuscle', 'fall', 'crepuscule', 'dusk', 'gloaming', 'gloam'}
#
# Słowo: merger
# Synonimy: {'amalgamation', 'fusion', 'merger', 'unification', 'uniting'}
#
# Słowo: quake
# Synonimy: {'quiver', 'palpitate', 'seism', 'temblor', 'tremor', 'earthquake', 'quake'}
#
# Słowo: titan
# Synonimy: {'giant', 'behemoth', 'titan', 'colossus', 'Titan', 'heavyweight'}
#
# Słowo: smell
# Synonimy: {'flavor', 'aroma', 'odor', 'olfaction', 'odour', 'sense', 'olfactory_modality', 'sense_of_smell', 'olfactory_sensation', 'smelling', 'spirit', 'smell_out', 'tone', 'feeling', 'olfactory_perception', 'flavour', 'look', 'feel', 'smell', 'scent', 'reek', 'olfactory_property', 'smack'}
#
# Słowo: size
# Synonimy: {'size', 'sizing', 'size_of_it'}
#
# Słowo: charon
# Synonimy: {'Charon'}
#
# Słowo: cheops
# Synonimy: {'Cheops', 'Khufu'}
#
# Słowo: coordinate
# Synonimy: {'coordinate', 'organise', 'ordinate', 'align', 'co-ordinate', 'organize'}
#
# Słowo: disk
# Synonimy: {'saucer', 'disk', 'platter', 'magnetic_disc', 'disc', 'record', 'harrow', 'phonograph_record', 'magnetic_disk', 'phonograph_recording'}
#
# Słowo: entropy
# Synonimy: {'S', 'selective_information', 'randomness', 'entropy', 'information'}
#
# Słowo: speed
# Synonimy: {'travel_rapidly', 'bucket_along', 'accelerate', 'upper', 'stop_number', 'f_number', 'zip', 'hurry', 'hurrying', 'focal_ratio', 'pep_pill', 'belt_along', 'hie', 'speeding', 'hotfoot', 'rush', 'speed_up', 'swiftness', 'rush_along', 'speed', 'velocity', 'fastness', 'cannonball_along', 'quicken', 'hasten', 'pelt_along', 'step_on_it', 'race', 'amphetamine'}
#
# Słowo: occultation
# Synonimy: {'eclipse', 'occultation'}
#
# Słowo: hydrogen
# Synonimy: {'hydrogen', 'atomic_number_1', 'H'}
#
# Słowo: ephemeris
# Synonimy: {'ephemeris'}
#
# Słowo: constellations
# Synonimy: {'constellation', 'configuration'}
#
# Słowo: kepler
# Synonimy: {'Kepler', 'Johan_Kepler', 'Johannes_Kepler'}
